# %%
import numpy as np
import pandas as pd
import difflib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
#loading the data from the csv file to a pandas dataframe
movies_data = pd.read_csv('movies.csv')

# %%
#printing the first 5 row of the dataframe
movies_data.head()
# Out:
#    index     budget  ...                                               crew           director
# 0      0  237000000  ...  [{'name': 'Stephen E. Rivkin', 'gender': 0, 'd...      James Cameron
# 1      1  300000000  ...  [{'name': 'Dariusz Wolski', 'gender': 2, 'depa...     Gore Verbinski
# 2      2  245000000  ...  [{'name': 'Thomas Newman', 'gender': 2, 'depar...         Sam Mendes
# 3      3  250000000  ...  [{'name': 'Hans Zimmer', 'gender': 2, 'departm...  Christopher Nolan
# 4      4  260000000  ...  [{'name': 'Andrew Stanton', 'gender': 2, 'depa...     Andrew Stanton
#
# [5 rows x 24 columns]

# %%
#no of rows and columns inthe dataset
movies_data.shape
# Out:
# (4803, 24)

# %%
#selectin the relevant features for recommendation
selected_features=['genres','keywords','tagline','cast','director']
print(selected_features)
# Out:
# ['genres', 'keywords', 'tagline', 'cast', 'director']

# %%
#replacing the null values with null string
for feature in selected_features:
  movies_data[feature]=movies_data[feature].fillna('')

# %%
#combining all the file slected features
combined_features=movies_data['genres']+' '+movies_data['keywords']+''+movies_data['tagline']+' '+movies_data['cast']+' '+movies_data['director']

# %%
print(combined_features)
# Out:
# 0       Action Adventure Fantasy Science Fiction cultu...
# 1       Adventure Fantasy Action ocean drug abuse exot...
# 2       Action Adventure Crime spy based on novel secr...
# 3       Action Crime Drama Thriller dc comics crime fi...
# 4       Action Adventure Science Fiction based on nove...
#                               ...
# 4798    Action Crime Thriller united states\u2013mexic...
# 4799    Comedy Romance A newlywed couple's honeymoon i...
# 4800    Comedy Drama Romance TV Movie date love at fir...
# 4801     A New Yorker in Shanghai Daniel Henney Eliza ...
# 4802    Documentary obsession camcorder crush dream gi...
# Length: 4803, dtype: object

# %%
#ocnverting the text data to feature vector
vectorizer=TfidfVectorizer()

# %%
feature_vectors=vectorizer.fit_transform(combined_features)

# %%
print(feature_vectors)
# Out:
#   (0, 229)	0.07905303662443708
#   (0, 325)	0.09077994724376506
#   (0, 6265)	0.1117623809081125
#   (0, 15922)	0.10438430008517753
#   (0, 6451)	0.1042622339194933
#   (0, 4316)	0.21507760818148391
#   (0, 3561)	0.22831712302293364
#   (0, 7007)	0.16761913103948795
#   (0, 16843)	0.3463021691447409
#   (0, 19434)	0.12763467115712607
#   (0, 3741)	0.2569035071769314
#   (0, 16721)	0.28682283809133036
#   (0, 17938)	0.07835679145512903
#   (0, 19935)	0.1296922122527455
#   (0, 13114)	0.09102271907804357
#   (0, 13458)	0.2735833232498806
#   (0, 15641)	0.15102423741048945
#   (0, 19951)	0.2377107082949574
#   (0, 20254)	0.2030704154867694
#   (0, 15611)	0.2189235377509099
#   (0, 16470)	0.20707370758386553
#   (0, 19540)	0.20065059297287455
#   (0, 17141)	0.152325312366219
#   (0, 10299)	0.22831712302293364
#   (0, 11950)	0.16145450217509352
#   :	:
#   (4801, 520)	0.17717587569273874
#   (4801, 5749)	0.24699827490898948
#   (4801, 20230)	0.28844705455386305
# ...

# %% [markdown]
# cosine similarity

# %%
#getting the similarity scores using cosine similarity
similarity=cosine_similarity(feature_vectors)

# %%
print(similarity)
# Out:
# [[1.         0.07376915 0.03750476 ... 0.         0.         0.        ]
#  [0.07376915 1.         0.03276527 ... 0.01216731 0.         0.        ]
#  [0.03750476 0.03276527 1.         ... 0.         0.05322545 0.        ]
#  ...
#  [0.         0.01216731 0.         ... 1.         0.         0.02626214]
#  [0.         0.         0.05322545 ... 0.         1.         0.        ]
#  [0.         0.         0.         ... 0.02626214 0.         1.        ]]

# %%
print(similarity.shape)
# Out:
# (4803, 4803)

# %%
#getting the movie name from the user

movie_name=input('enter your favourite movie name:')
# Out:
# enter your favourite movie name:iron man

# %%
#creating a list with all the movie names given in the dataset
list_of_all_titles=movies_data['title'].tolist()
print(list_of_all_titles)
# Out:
# ['Avatar', "Pirates of the Caribbean: At World's End", 'Spectre', 'The Dark Knight Rises', 'John Carter', 'Spider-Man 3', 'Tangled', 'Avengers: Age of Ultron', 'Harry Potter and the Half-Blood Prince', 'Batman v Superman: Dawn of Justice', 'Superman Returns', 'Quantum of Solace', "Pirates of the Caribbean: Dead Man's Chest", 'The Lone Ranger', 'Man of Steel', 'The Chronicles of Narnia: Prince Caspian', 'The Avengers', 'Pirates of the Caribbean: On Stranger Tides', 'Men in Black 3', 'The Hobbit: The Battle of the Five Armies', 'The Amazing Spider-Man', 'Robin Hood', 'The Hobbit: The Desolation of Smaug', 'The Golden Compass', 'King Kong', 'Titanic', 'Captain America: Civil War', 'Battleship', 'Jurassic World', 'Skyfall', 'Spider-Man 2', 'Iron Man 3', 'Alice in Wonderland', 'X-Men: The Last Stand', 'Monsters University', 'Transformers: Revenge of the Fallen', 'Transformers: Age of Extinction', 'Oz: The Great and Powerful', 'The Amazing Spider-Man 2', 'TRON: Legacy', 'Cars 2', 'Green La
# ...

# %%
#finiding the close march for the movie name given by the user
find_close_match=difflib.get_close_matches(movie_name,list_of_all_titles)
print(find_close_match)
# Out:
# ['Iron Man', 'Iron Man 3', 'Iron Man 2']

# %%
close_match=find_close_match[0]
print(close_match)
# Out:
# Iron Man

# %%
#fndng the index of the movie with title
index_of_the_movie=movies_data[movies_data.title==close_match]['index'].values[0]
print(index_of_the_movie)
# Out:
# 68

# %%
similarity_score=list(enumerate(similarity[index_of_the_movie]))
print(similarity_score)
# Out:
# [(0, 0.03357281107557475), (1, 0.053553592905273124), (2, 0.013491723161270506), (3, 0.006339287522285405), (4, 0.0324864351994576), (5, 0.013656297581519056), (6, 0.05766534389198674), (7, 0.20286705312599015), (8, 0.007891517635811134), (9, 0.04475905355914801), (10, 0.03721704947985334), (11, 0.012103296949685096), (12, 0.013431531888969167), (13, 0.012143463537600662), (14, 0.06391935753443978), (15, 0.007224636025065483), (16, 0.19374171472943857), (17, 0.013046152975378304), (18, 0.024040915632757308), (19, 0.077815360809466), (20, 0.07895932316373197), (21, 0.01170074538831609), (22, 0.007069511208179688), (23, 0.006514872560318135), (24, 0.012372112770030991), (25, 0.0), (26, 0.18254782023656563), (27, 0.02988363030518345), (28, 0.05918237314267773), (29, 0.014081403716457639), (30, 0.08014604139045069), (31, 0.2829738758802927), (32, 0.02858660803908218), (33, 0.13280275593074425), (34, 0.0), (35, 0.035611261742187886), (36, 0.0325319980329728), (37, 0.007907911217637476), (
# ...

# %%
sorted_similar_movies=sorted(similarity_score,key=lambda x:x[1],reverse=True)
print(sorted_similar_movies)
# Out:
# [(68, 1.0000000000000002), (79, 0.36810382315937396), (31, 0.2829738758802927), (7, 0.20286705312599015), (16, 0.19374171472943857), (26, 0.18254782023656563), (3623, 0.15760635787462524), (4401, 0.14415566593882329), (46, 0.14345836166800274), (511, 0.13726318478047347), (33, 0.13280275593074425), (783, 0.1324421011189832), (182, 0.12503351576058347), (2651, 0.12267085643209247), (85, 0.1226556399954735), (2487, 0.12166498155235392), (64, 0.11877435778742718), (203, 0.11846663237966179), (1553, 0.1178751625347452), (138, 0.11705381467150687), (174, 0.11615310772631524), (38, 0.1153120861179381), (353, 0.11416230147426328), (607, 0.11097860930398785), (101, 0.10851648473605105), (661, 0.10735251485146421), (126, 0.10571256820923888), (788, 0.10328505656718436), (1210, 0.10256531286760884), (1740, 0.10166530992151934), (954, 0.1005772067842353), (720, 0.09996319907871098), (94, 0.09750380100972297), (3385, 0.0973276180565385), (307, 0.09711855437675282), (2235, 0.09631810529211642), (
# ...

# %%
#print the name of similar movie based on the index
print('movies suggested for you: \n')
i=1
for movie in sorted_similar_movies:
  index=movie[0]
  title_from_index=movies_data[movies_data.index==index]['title'].values[0]
  if(i<30):
    print(i,'.',title_from_index)
    i+=1
# Out:
# movies suggested for you:
#
# 1 . Iron Man
# 2 . Iron Man 2
# 3 . Iron Man 3
# 4 . Avengers: Age of Ultron
# 5 . The Avengers
# 6 . Captain America: Civil War
# 7 . Made
# 8 . The Helix... Loaded
# 9 . X-Men: Days of Future Past
# 10 . X-Men
# 11 . X-Men: The Last Stand
# 12 . Mortdecai
# 13 . Ant-Man
# 14 . The Good Night
# 15 . Captain America: The Winter Soldier
# 16 . Duets
# 17 . X-Men: Apocalypse
# 18 . X2
# 19 . Se7en
# 20 . The Last Airbender
# 21 . The Incredible Hulk
# 22 . The Amazing Spider-Man 2
# 23 . Tropic Thunder
# 24 . Sky Captain and the World of Tomorrow
# 25 . X-Men: First Class
# 26 . Zathura: A Space Adventure
# 27 . Thor: The Dark World
# 28 . Deadpool
# 29 . Gothika

# %% [markdown]
# movie recommendation system

# %%
movie_name=input('enter your favourite movie name:')
list_of_all_titles=movies_data['title'].tolist()
find_close_match=difflib.get_close_matches(movie_name,list_of_all_titles)
close_match=find_close_match[0]
index_of_the_movie=movies_data[movies_data.title==close_match]['index'].values[0]
similarity_score=list(enumerate(similarity[index_of_the_movie]))
sorted_similar_movies=sorted(similarity_score,key=lambda x:x[1],reverse=True)
print('movies suggested for you: \n')
i=1
for movie in sorted_similar_movies:
  index=movie[0]
  title_from_index=movies_data[movies_data.index==index]['title'].values[0]
  if(i<30):
    print(i,'.',title_from_index)
    i+=1
# Out:
# enter your favourite movie name:anime
# movies suggested for you:
#
# 1 . In Time
# 2 . The Helix... Loaded
# 3 . The Host
# 4 . Endless Love
# 5 . TRON: Legacy
# 6 . Death Race
# 7 . Gattaca
# 8 . Repo Man
# 9 . Magic Mike
# 10 . Ted 2
# 11 . No Escape
# 12 . I Am Number Four
# 13 . Sunshine
# 14 . RoboCop
# 15 . The Time Machine
# 16 . The Big Wedding
# 17 . Automata
# 18 . Beastly
# 19 . Good Kill
# 20 . Looper
# 21 . The Dead Zone
# 22 . The Incredible Burt Wonderstone
# 23 . The Musketeer
# 24 . Mutual Appreciation
# 25 . FearDotCom
# 26 . Sleeper
# 27 . The Last Days on Mars
# 28 . Perrier’s Bounty
# 29 . Lord of War
